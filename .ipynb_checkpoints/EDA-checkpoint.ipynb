# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
df = pd.read_csv('nyc_census_tracts.csv')
print('dataframe shape: ', df.shape)
df.head()
# Out:
# dataframe shape:  (2167, 36)
#    CensusTract County Borough  TotalPop   Men  Women  Hispanic  White  Black  \
# 0  36005000100  Bronx   Bronx      7703  7133    570      29.9    6.1   60.9
# 1  36005000200  Bronx   Bronx      5403  2659   2744      75.8    2.3   16.0
# 2  36005000400  Bronx   Bronx      5915  2896   3019      62.7    3.6   30.7
# 3  36005001600  Bronx   Bronx      5879  2558   3321      65.1    1.6   32.4
# 4  36005001900  Bronx   Bronx      2591  1206   1385      55.4    9.0   29.0
#
#    Native  ...  Walk  OtherTransp  WorkAtHome  MeanCommute  Employed  \
# 0     0.2  ...   NaN          NaN         NaN          NaN         0
# 1     0.0  ...   2.9          0.0         0.0         43.0      2308
# 2     0.0  ...   1.4          0.5         2.1         45.0      2675
# 3     0.0  ...   8.6          1.6         1.7         38.8      2120
# 4     0.0  ...   3.0          2.4         6.2         45.4      1083
#
#    PrivateWork  PublicWork  SelfEmployed  FamilyWork  Unemployment
# 0          NaN         NaN           NaN         NaN           NaN
# 1         80.8        16.2           2.9         0.0           7.7
# 2         71.7        25.3           2.5         0.6           9.5
# 3         75.0        21.3           3.8         0.0           8.7
# 4         76.8        15.5           7.7         0.0          19.2
#
# [5 rows x 36 columns]

# %%
# So there are 2176 rows for the data and 36 columns. We probably don't need all columns.

df.columns
# Out:
# Index(['CensusTract', 'County', 'Borough', 'TotalPop', 'Men', 'Women',
#        'Hispanic', 'White', 'Black', 'Native', 'Asian', 'Citizen', 'Income',
#        'IncomeErr', 'IncomePerCap', 'IncomePerCapErr', 'Poverty',
#        'ChildPoverty', 'Professional', 'Service', 'Office', 'Construction',
#        'Production', 'Drive', 'Carpool', 'Transit', 'Walk', 'OtherTransp',
#        'WorkAtHome', 'MeanCommute', 'Employed', 'PrivateWork', 'PublicWork',
#        'SelfEmployed', 'FamilyWork', 'Unemployment'],
#       dtype='object')

# %%
# They all look pretty usefull potentially. CensusTract looks like just an ID so useless.
df = df.drop(columns = 'CensusTract')
df.head()
# Out:
#   County Borough  TotalPop   Men  Women  Hispanic  White  Black  Native  \
# 0  Bronx   Bronx      7703  7133    570      29.9    6.1   60.9     0.2
# 1  Bronx   Bronx      5403  2659   2744      75.8    2.3   16.0     0.0
# 2  Bronx   Bronx      5915  2896   3019      62.7    3.6   30.7     0.0
# 3  Bronx   Bronx      5879  2558   3321      65.1    1.6   32.4     0.0
# 4  Bronx   Bronx      2591  1206   1385      55.4    9.0   29.0     0.0
#
#    Asian  ...  Walk  OtherTransp  WorkAtHome  MeanCommute  Employed  \
# 0    1.6  ...   NaN          NaN         NaN          NaN         0
# 1    4.2  ...   2.9          0.0         0.0         43.0      2308
# 2    0.3  ...   1.4          0.5         2.1         45.0      2675
# 3    0.0  ...   8.6          1.6         1.7         38.8      2120
# 4    2.1  ...   3.0          2.4         6.2         45.4      1083
#
#    PrivateWork  PublicWork  SelfEmployed  FamilyWork  Unemployment
# 0          NaN         NaN           NaN         NaN           NaN
# 1         80.8        16.2           2.9         0.0           7.7
# 2         71.7        25.3           2.5         0.6           9.5
# 3         75.0        21.3           3.8         0.0           8.7
# 4         76.8        15.5           7.7         0.0          19.2
#
# [5 rows x 35 columns]

# %% [markdown]
# #EDA

# %%
# visualization stuffs
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# sns.pairplot(df)
# Can't run this because the values are too big

# %%
df.describe()
# Out:
#            TotalPop           Men         Women     Hispanic        White  \
# count   2167.000000   2167.000000   2167.000000  2128.000000  2128.000000
# mean    3888.667743   1852.812183   2035.855561    26.624671    33.055827
# std     2240.050968   1063.921420   1212.765249    22.662106    30.421463
# min        0.000000      0.000000      0.000000     0.000000     0.000000
# 25%     2359.500000   1113.000000   1224.500000     9.000000     4.100000
# 50%     3550.000000   1699.000000   1848.000000    18.400000    22.950000
# 75%     4957.500000   2360.500000   2571.500000    39.900000    60.100000
# max    28926.000000  13460.000000  15466.000000   100.000000   100.000000
#
#              Black       Native        Asian       Citizen         Income  \
# count  2128.000000  2128.000000  2128.000000   2167.000000    2101.000000
# mean     23.950799     0.198590    13.442622   2436.468389   59101.320800
# std      29.476758     0.700418    16.446275   1538.399585   28802.662945
# min       0.000000     0.000000     0.000000      0.000000    9829.000000
# 25%       1.500000     0.000000     2.100000   1446.000000   39073.000000
# 50%       7.800000     0.000000     6.700000   2140.000000   54505.000000
# 75%      39.075000     0.000000    18.925000   2976.000000   73272.000000
# max     100.000000    11.300000    89.800000  22905.000000  244375.000000
#
#        ...         Walk  OtherTransp   WorkAtHome  MeanCommute      Employed  \
# count  ...  2124.000000  2124.000000  2124.000000  2106.000000   2167.000000
# mean   ...     9.048070     2.306921     3.749105    40.831576   1813.498385
# std    ...     9.623892     2.872501     4.560174     7.105916   1180.593180
# min    ...     0.000000     0.000000     0.000000    15.200000      0.000000
# 25%    ...     3.300000     0.500000     1.300000    37.200000   1052.500000
# 50%    ...     6.500000     1.500000     2.800000    41.400000   1579.000000
# 75%    ...    10.800000     3.200000     5.100000    45.375000   2273.500000
# max    ...   100.000000    55.600000   100.000000    70.500000  12780.000000
#
#        PrivateWork  PublicWork  SelfEmployed   FamilyWork  Unemployment
# count  2124.000000  2124.00000   2124.000000  2124.000000   2125.000000
# mean     79.536205    14.19355      6.151271     0.118644      9.757788
# std       6.923979     7.23155      3.851846     0.391563      5.786948
# min      38.600000     0.00000      0.000000     0.000000      0.000000
# 25%      75.000000     8.80000      3.500000     0.000000      5.900000
# 50%      79.900000    13.30000      5.600000     0.000000      8.800000
# 75%      84.400000    18.70000      8.200000     0.000000     12.600000
# max     100.000000    53.70000     61.400000     3.900000    100.000000
#
# [8 rows x 33 columns]

# %%
df.groupby('Borough').sum()
# Out:
#                TotalPop      Men    Women  Hispanic    White    Black  Native  \
# Borough
# Bronx           1428357   672447   755910   17626.4   4340.0   9735.6    68.9
# Brooklyn        2595259  1229001  1366258   13709.8  28013.5  23530.0   136.5
# Manhattan       1629507   769434   860073    6408.9  13638.9   3927.5    63.5
# Queens          2301139  1115459  1185680   16909.4  17770.7  12603.8   144.3
# Staten Island    472481   228703   243778    2002.8   6579.7   1170.4     9.4
#
#                  Asian  Citizen      Income  ...    Walk  OtherTransp  \
# Borough                                      ...
# Bronx           1270.2   820317  12933386.0  ...  2684.6        584.6
# Brooklyn        8292.2  1601527  40590155.0  ...  6524.2       1732.3
# Manhattan       3460.1  1156936  22921786.0  ...  6117.9       1479.8
# Queens         14746.9  1367889  40020276.0  ...  3553.5       1005.2
# Staten Island    836.5   333158   7706272.0  ...   337.9         98.0
#
#                WorkAtHome  MeanCommute  Employed  PrivateWork  PublicWork  \
# Borough
# Bronx              1116.7      14023.6    563903      26862.7      4887.5
# Brooklyn           2771.7      31333.4   1167448      59081.0     11209.4
# Manhattan          2027.7       8579.5    884457      23395.7      2476.8
# Queens             1744.3      27541.0   1104930      51552.3      9291.6
# Staten Island       302.7       4513.8    209113       8043.2      2281.8
#
#                SelfEmployed  FamilyWork  Unemployment
# Borough
# Bronx                1710.3        39.1        4635.0
# Brooklyn             4635.1        73.6        7469.0
# Manhattan            2181.1        46.4        2257.3
# Queens               4070.7        85.5        5601.7
# Staten Island         468.1         7.4         772.3
#
# [5 rows x 33 columns]

# %%
# Bar Charts
df.groupby('Borough').sum()['WorkAtHome'].index.tolist()
# Out:
# ['Bronx', 'Brooklyn', 'Manhattan', 'Queens', 'Staten Island']

# %%
df.groupby('Borough').sum()['WorkAtHome'].values.round().tolist()
# Out:
# [1117.0, 2772.0, 2028.0, 1744.0, 303.0]

# %%
names_list = df.groupby('Borough').sum()['WorkAtHome'].index.tolist()

# %%
values_list = df.groupby('Borough').sum()['WorkAtHome'].values.round().tolist()

# %%
fig, ax = plt.subplots(figsize=(6, 4))
plt.bar(np.arange(len(values_list)), values_list, align='center', alpha=0.7, color='violet')
plt.xticks(np.arange(len(names_list)), names_list)
plt.ylabel('Working At Home')
plt.xlabel('Borough')
plt.title('Total Working At Home In NYC')
# Out:
# Text(0.5, 1.0, 'Total Working At Home In NYC')

# %% [markdown]
# It looks like in Staten Island not many work from home. Where do they work?

# %%
# data handlers
import numpy as np
import pandas as pd


# data visualization stuffs
import matplotlib.pyplot as plt
import seaborn as sns 


# ML algorithms
from sklearn.linear_model import LinearRegression, Lasso, Ridge
from sklearn.svm import SVR


# sklearn stuffs
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.preprocessing import StandardScaler, PowerTransformer
from sklearn.metrics import r2_score, mean_squared_error

np.random.seed(42)

# %%
def plot_heatmap(df):
    
    """
    This function first creates a correlation matrix then visualizae 
    the correlation matrix using a heatmap from seaborn.
    """
    # heat map of correlation matrix
    # corr matrix
    df_cor = df.corr()
    
    # make figure
    plt.figure(figsize=(12, 10))
    sns.heatmap(df_cor, annot=True)
    plt.tight_layout()
    plt.show()

# %%
plot_heatmap(df)

# %% [markdown]
# omg...

# %%
df = df.dropna()

# %%
# split dataset into training and testing
y_red = df['Income'].values
feature_list = ['Men', 'Women', 'Hispanic', 'White', 'Black', 'Native', 'Asian', 'Citizen', 'MeanCommute']
x_red = df[feature_list]

# %%
df.dropna().shape
# Out:
# (2095, 35)

# %%
x_red.shape, y_red.shape, df.shape
# Out:
# ((2095, 9), (2095,), (2095, 35))

# %%
# split into train test sets
trainFeatures, testFeatures, trainIncome, testIncome = train_test_split(x_red, y_red, train_size=0.75, random_state=42)

# %%
trainFeatures.shape
# Out:
# (1571, 9)

# %%
testFeatures.shape
# Out:
# (524, 9)

# %%
trainIncome.shape
# Out:
# (1571,)

# %%
testIncome.shape
# Out:
# (542,)

# %%
scaler = StandardScaler()
scaler.fit(trainFeatures)
trainFeatures = scaler.transform(trainFeatures)
testFeatures = scaler.transform(testFeatures)

# %%
trainFeatures
# Out:
# array([[-8.85549351e-01, -7.22248110e-01, -6.66620701e-01, ...,
#         -7.85012716e-01, -6.08495901e-01,  7.11475373e-01],
#        [-1.15472767e+00, -1.09460255e+00, -9.56691859e-01, ...,
#         -6.87300614e-01, -1.05137488e+00,  2.05915846e-03],
#        [-7.13628893e-01, -7.12960357e-01, -2.22449242e-01, ...,
#          1.92039111e+00, -5.04327621e-01, -4.80343868e-01],
#        ...,
#        [ 4.13186910e-01,  4.96136136e-01, -9.11368240e-01, ...,
#         -2.29275135e-01,  1.12567665e+00, -2.48089759e+00],
#        [-5.80022137e-01, -1.18078769e-03,  1.37747448e+00, ...,
#         -5.22411441e-01, -5.48971825e-02,  3.04358070e-02],
#        [-1.06729384e+00, -1.02030053e+00, -7.21009043e-01, ...,
#          1.55466268e-01, -8.83002247e-01,  2.43260671e-01]])

# %%
testFeatures
# Out:
# array([[ 1.88286123,  3.09586246, -0.08647839, ..., -0.80333373,
#          3.02953213,  0.69728705],
#        [-1.13704442, -1.35719264, -0.92949769, ...,  1.27304844,
#         -1.12802701, -2.45252094],
#        [ 1.41327277,  0.11533829, -0.80712392, ..., -0.3880573 ,
#          1.44407781, -2.56602754],
#        ...,
#        [ 0.97020919,  0.6371411 , -0.74367085, ..., -0.52241144,
#          1.34056468, -0.36683727],
#        [-1.11248436, -0.95106456, -0.81165628, ..., -0.70562163,
#         -0.77883397, -0.74992203],
#        [ 0.51633918,  0.9039529 , -0.63489417, ..., -0.83997577,
#          0.57993969,  0.24326067]])

# %%
lr = LinearRegression()

# %%
# first seed

np.random.seed(42)

# FIT THE MODEL
lr.fit(trainFeatures, trainIncome)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
df[df.isna()]
# Out:
#      County Borough  TotalPop  Men  Women  Hispanic  White  Black  Native  \
# 0       NaN     NaN       NaN  NaN    NaN       NaN    NaN    NaN     NaN
# 1       NaN     NaN       NaN  NaN    NaN       NaN    NaN    NaN     NaN
# 2       NaN     NaN       NaN  NaN    NaN       NaN    NaN    NaN     NaN
# 3       NaN     NaN       NaN  NaN    NaN       NaN    NaN    NaN     NaN
# 4       NaN     NaN       NaN  NaN    NaN       NaN    NaN    NaN     NaN
# ...     ...     ...       ...  ...    ...       ...    ...    ...     ...
# 2162    NaN     NaN       NaN  NaN    NaN       NaN    NaN    NaN     NaN
# 2163    NaN     NaN       NaN  NaN    NaN       NaN    NaN    NaN     NaN
# 2164    NaN     NaN       NaN  NaN    NaN       NaN    NaN    NaN     NaN
# 2165    NaN     NaN       NaN  NaN    NaN       NaN    NaN    NaN     NaN
# 2166    NaN     NaN       NaN  NaN    NaN       NaN    NaN    NaN     NaN
#
#       Asian  ...  Walk  OtherTransp  WorkAtHome  MeanCommute  Employed  \
# 0       NaN  ...   NaN          NaN         NaN          NaN       NaN
# 1       NaN  ...   NaN          NaN         NaN          NaN       NaN
# 2       NaN  ...   NaN          NaN         NaN          NaN       NaN
# 3       NaN  ...   NaN          NaN         NaN          NaN       NaN
# 4       NaN  ...   NaN          NaN         NaN          NaN       NaN
# ...     ...  ...   ...          ...         ...          ...       ...
# 2162    NaN  ...   NaN          NaN         NaN          NaN       NaN
# 2163    NaN  ...   NaN          NaN         NaN          NaN       NaN
# 2164    NaN  ...   NaN          NaN         NaN          NaN       NaN
# 2165    NaN  ...   NaN          NaN         NaN          NaN       NaN
# 2166    NaN  ...   NaN          NaN         NaN          NaN       NaN
#
#       PrivateWork  PublicWork  SelfEmployed  FamilyWork  Unemployment
# 0             NaN         NaN           NaN         NaN           NaN
# 1             NaN         NaN           NaN         NaN           NaN
# 2             NaN         NaN           NaN         NaN           NaN
# 3             NaN         NaN           NaN         NaN           NaN
# 4             NaN         NaN           NaN         NaN           NaN
# ...           ...         ...           ...         ...           ...
# 2162          NaN         NaN           NaN         NaN           NaN
# 2163          NaN         NaN           NaN         NaN           NaN
# 2164          NaN         NaN           NaN         NaN           NaN
# 2165          NaN         NaN           NaN         NaN           NaN
# 2166          NaN         NaN           NaN         NaN           NaN
#
# [2167 rows x 35 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2167 entries, 0 to 2166
# Data columns (total 35 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   County           2167 non-null   object
#  1   Borough          2167 non-null   object
#  2   TotalPop         2167 non-null   int64
#  3   Men              2167 non-null   int64
#  4   Women            2167 non-null   int64
#  5   Hispanic         2128 non-null   float64
#  6   White            2128 non-null   float64
#  7   Black            2128 non-null   float64
#  8   Native           2128 non-null   float64
#  9   Asian            2128 non-null   float64
#  10  Citizen          2167 non-null   int64
#  11  Income           2101 non-null   float64
#  12  IncomeErr        2101 non-null   float64
#  13  IncomePerCap     2121 non-null   float64
#  14  IncomePerCapErr  2121 non-null   float64
#  15  Poverty          2125 non-null   float64
#  16  ChildPoverty     2107 non-null   float64
#  17  Professional     2124 non-null   float64
#  18  Service          2124 non-null   float64
#  19  Office           2124 non-null   float64
#  20  Construction     2124 non-null   float64
#  21  Production       2124 non-null   float64
#  22  Drive            2124 non-null   float64
#  23  Carpool          2124 non-null   float64
#  24  Transit          2124 non-null   float64
#  25  Walk             2124 non-null   float64
#  26  OtherTransp      2124 non-null   float64
#  27  WorkAtHome       2124 non-null   float64
#  28  MeanCommute      2106 non-null   float64
#  29  Employed         2167 non-null   int64
#  30  PrivateWork      2124 non-null   float64
#  31  PublicWork       2124 non-null   float64
#  32  SelfEmployed     2124 non-null   float64
#  33  FamilyWork       2124 non-null   float64
#  34  Unemployment     2125 non-null   float64
# dtypes: float64(28), int64(5), object(2)
# memory usage: 592.7+ KB

# %%
# Out:
# (2095, 35)
